# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import json 
import requests
import timeit

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module.
cities = []
coordinates = list(lat_lngs)
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
         cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Perform an API call with the OpenWeatherMap.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve information from the API call:

# Create an empty list to hold the weather data.
city_data = []
#provide initial print info"
print("Begin the data retrieval...    ")
print("-----------------------------")

#Initiate counters
record_count = 1
set_count = 1
# Out:
# Begin the data retrieval...
# -----------------------------

# %%
import time
from datetime import datetime

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | chuy
# Processing Record 2 of Set 1 | los llanos de aridane
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | mantua
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | chivilcoy
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | biloela
# Processing Record 11 of Set 1 | camapua
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | sokoni
# Processing Record 16 of Set 1 | arroyo
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | souillac
# Processing Record 19 of Set 1 | alice springs
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | batticaloa
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | lodja
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | ketchenery
# City not found. Skipping...
# Processing Record 30 of Set 1 | kimbe
# Processing Record 31 of Set 1 | caravelas
# Processing Record 32 of Set 1 | touros
# Processing Record 33 of Set 1 | saint george
# Processing Record 34 of Set 1 | bulaevo
# Processing Record 35 of Set 1 | kailua
# Processing Record 36 of Set 1 | dalby
# Processing Record 37 of Set 1 | sakakah
# Processing Record 38 of Set 1 | sonegaon
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | khani
# Processing Record 45 of Set 1 | thurso
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | victoria
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | namibe
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | palmer
# Processing Record 3 of Set 2 | kirakira
# Processing Record 4 of Set 2 | flinders
# Processing Record 5 of Set 2 | cayenne
# Processing Record 6 of Set 2 | saskylakh
# Processing Record 7 of Set 2 | geraldton
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | viedma
# Processing Record 10 of Set 2 | ilulissat
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | chernyshevskiy
# Processing Record 13 of Set 2 | manicore
# Processing Record 14 of Set 2 | kalmunai
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | airai
# Processing Record 17 of Set 2 | khadyzhensk
# Processing Record 18 of Set 2 | ancud
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 2 | roma
# Processing Record 22 of Set 2 | lompoc
# Processing Record 23 of Set 2 | moerai
# Processing Record 24 of Set 2 | chernushka
# Processing Record 25 of Set 2 | brigantine
# Processing Record 26 of Set 2 | kununurra
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 2 | lavrentiya
# Processing Record 30 of Set 2 | talnakh
# Processing Record 31 of Set 2 | cabo san lucas
# Processing Record 32 of Set 2 | savannah bight
# Processing Record 33 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 2 | leningradskiy
# Processing Record 35 of Set 2 | pasighat
# Processing Record 36 of Set 2 | mahon
# Processing Record 37 of Set 2 | edson
# Processing Record 38 of Set 2 | antofagasta
# Processing Record 39 of Set 2 | smoljan
# Processing Record 40 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | dunedin
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | jamsa
# Processing Record 48 of Set 2 | north platte
# Processing Record 49 of Set 2 | klaksvik
# Processing Record 50 of Set 2 | yuncheng
# Processing Record 1 of Set 3 | santander
# Processing Record 2 of Set 3 | arecibo
# Processing Record 3 of Set 3 | yerbogachen
# Processing Record 4 of Set 3 | sinjai
# Processing Record 5 of Set 3 | makakilo city
# Processing Record 6 of Set 3 | busselton
# Processing Record 7 of Set 3 | cidreira
# Processing Record 8 of Set 3 | locri
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 3 | kahului
# Processing Record 11 of Set 3 | tawau
# Processing Record 12 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 3 | venkatagiri
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | dnestrovsc
# Processing Record 16 of Set 3 | abu kamal
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | havelock
# Processing Record 19 of Set 3 | broska
# Processing Record 20 of Set 3 | belyy yar
# Processing Record 21 of Set 3 | santa cruz
# Processing Record 22 of Set 3 | freetown
# Processing Record 23 of Set 3 | richards bay
# Processing Record 24 of Set 3 | pisco
# Processing Record 25 of Set 3 | pemangkat
# Processing Record 26 of Set 3 | soyo
# Processing Record 27 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | guerrero negro
# Processing Record 30 of Set 3 | whitehorse
# Processing Record 31 of Set 3 | cortez
# Processing Record 32 of Set 3 | leshan
# Processing Record 33 of Set 3 | esperance
# Processing Record 34 of Set 3 | zhigansk
# Processing Record 35 of Set 3 | berlevag
# Processing Record 36 of Set 3 | batagay-alyta
# Processing Record 37 of Set 3 | fukuma
# Processing Record 38 of Set 3 | tete
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | hay river
# Processing Record 41 of Set 3 | camacha
# Processing Record 42 of Set 3 | tuktoyaktuk
# Processing Record 43 of Set 3 | carnot
# Processing Record 44 of Set 3 | rocha
# Processing Record 45 of Set 3 | ust-kuyga
# Processing Record 46 of Set 3 | sao joao da barra
# Processing Record 47 of Set 3 | new norfolk
# Processing Record 48 of Set 3 | sao filipe
# Processing Record 49 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 3 | ranong

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
