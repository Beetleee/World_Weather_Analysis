# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import json 
import requests
import timeit

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module.
cities = []
coordinates = list(lat_lngs)
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
         cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Perform an API call with the OpenWeatherMap.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve information from the API call:

# Create an empty list to hold the weather data.
city_data = []
#provide initial print info"
print("Begin the data retrieval...    ")
print("-----------------------------")

#Initiate counters
record_count = 1
set_count = 1
# Out:
# Begin the data retrieval...
# -----------------------------

# %%
import time
from datetime import datetime

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | aykhal
# Processing Record 3 of Set 1 | harnosand
# Processing Record 4 of Set 1 | salalah
# Processing Record 5 of Set 1 | lompoc
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | nizhniy kuranakh
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | hasaki
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | leshukonskoye
# Processing Record 13 of Set 1 | borogontsy
# Processing Record 14 of Set 1 | beloha
# Processing Record 15 of Set 1 | ketchikan
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 1 | luderitz
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 1 | sao joao da barra
# Processing Record 24 of Set 1 | kommunisticheskiy
# Processing Record 25 of Set 1 | san cristobal
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | buraydah
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | bijar
# Processing Record 35 of Set 1 | beringovskiy
# Processing Record 36 of Set 1 | mysliborz
# Processing Record 37 of Set 1 | pasighat
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | muros
# Processing Record 40 of Set 1 | hofn
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | palembang
# Processing Record 44 of Set 1 | pangnirtung
# Processing Record 45 of Set 1 | namatanai
# Processing Record 46 of Set 1 | glendive
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | laishevo
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | bubaque
# Processing Record 8 of Set 2 | auki
# Processing Record 9 of Set 2 | rawson
# Processing Record 10 of Set 2 | vetlanda
# Processing Record 11 of Set 2 | apac
# Processing Record 12 of Set 2 | klaksvik
# Processing Record 13 of Set 2 | kankan
# Processing Record 14 of Set 2 | ravar
# Processing Record 15 of Set 2 | hambantota
# Processing Record 16 of Set 2 | yushu
# Processing Record 17 of Set 2 | quatre cocos
# Processing Record 18 of Set 2 | dingle
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | codrington
# Processing Record 23 of Set 2 | buxton
# Processing Record 24 of Set 2 | havre-saint-pierre
# Processing Record 25 of Set 2 | sisimiut
# Processing Record 26 of Set 2 | okhotsk
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | kruisfontein
# Processing Record 29 of Set 2 | chernaya kholunitsa
# Processing Record 30 of Set 2 | victoria
# Processing Record 31 of Set 2 | iqaluit
# Processing Record 32 of Set 2 | parana
# Processing Record 33 of Set 2 | guayaramerin
# Processing Record 34 of Set 2 | charlottesville
# Processing Record 35 of Set 2 | longyearbyen
# Processing Record 36 of Set 2 | san ramon
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | andra
# Processing Record 39 of Set 2 | bathsheba
# Processing Record 40 of Set 2 | cidreira
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | talnakh
# Processing Record 45 of Set 2 | tateyama
# Processing Record 46 of Set 2 | pacific grove
# Processing Record 47 of Set 2 | college
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | visconde do rio branco
# Processing Record 50 of Set 2 | vila velha
# Processing Record 1 of Set 3 | nikolskoye
# Processing Record 2 of Set 3 | umm kaddadah
# Processing Record 3 of Set 3 | kilindoni
# Processing Record 4 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | brusyliv
# Processing Record 7 of Set 3 | port blair
# Processing Record 8 of Set 3 | suicheng
# Processing Record 9 of Set 3 | george town
# Processing Record 10 of Set 3 | touros
# Processing Record 11 of Set 3 | glendale
# Processing Record 12 of Set 3 | tomatlan
# Processing Record 13 of Set 3 | marsa matruh
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | mount gambier
# Processing Record 16 of Set 3 | port hardy
# Processing Record 17 of Set 3 | dezhou
# Processing Record 18 of Set 3 | aksarka
# Processing Record 19 of Set 3 | usinsk
# Processing Record 20 of Set 3 | esperance
# Processing Record 21 of Set 3 | altamont
# Processing Record 22 of Set 3 | akdepe
# Processing Record 23 of Set 3 | alofi
# Processing Record 24 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 3 | north myrtle beach
# Processing Record 26 of Set 3 | new norfolk
# Processing Record 27 of Set 3 | souillac
# Processing Record 28 of Set 3 | avarua
# Processing Record 29 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | vestmannaeyjar
# Processing Record 32 of Set 3 | bonoua
# Processing Record 33 of Set 3 | nouadhibou
# Processing Record 34 of Set 3 | mehamn
# Processing Record 35 of Set 3 | jujuy
# City not found. Skipping...
# Processing Record 36 of Set 3 | clyde river
# Processing Record 37 of Set 3 | moiyabana
# City not found. Skipping...
# Processing Record 38 of Set 3 | fortuna
# Processing Record 39 of Set 3 | revda
# Processing Record 40 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 3 | castro
# Processing Record 42 of Set 3 | jamestown
# Processing Record 43 of Set 3 | norman wells
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | lushunkou
# City not found. Skipping...
# Processing Record 46 of Set 3 | inhambane
# Processing Record 47 of Set 3 | egvekinot
# Processing Record 48 of Set 3 | westport
# Processing Record 49 of Set 3 | ponta delgada
# Processing Record 50 of Set 3 | burica
# City not found. Skipping...
# Processing Record 1 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 2 of Set 4 | mahebourg
# Processing Record 3 of Set 4 | xai-xai
# Processing Record 4 of Set 4 | barrow
# Processing Record 5 of Set 4 | chokurdakh
# Processing Record 6 of Set 4 | rincon
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | kachug
# Processing Record 9 of Set 4 | bengkulu
# Processing Record 10 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 4 | tungkang
# City not found. Skipping...
# Processing Record 12 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 4 | lundazi
# Processing Record 14 of Set 4 | kawalu
# Processing Record 15 of Set 4 | dharchula
# Processing Record 16 of Set 4 | maniwaki
# Processing Record 17 of Set 4 | san ignacio
# Processing Record 18 of Set 4 | port elizabeth
# Processing Record 19 of Set 4 | aleksandrov
# Processing Record 20 of Set 4 | tuatapere
# Processing Record 21 of Set 4 | aksu
# Processing Record 22 of Set 4 | iwanai
# Processing Record 23 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 4 | saint-pierre
# Processing Record 25 of Set 4 | twin falls
# Processing Record 26 of Set 4 | sitka
# Processing Record 27 of Set 4 | ulaangom
# Processing Record 28 of Set 4 | chuy
# Processing Record 29 of Set 4 | lavrentiya
# Processing Record 30 of Set 4 | atuona
# Processing Record 31 of Set 4 | neepawa
# Processing Record 32 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 4 | ubajara
# Processing Record 34 of Set 4 | cabo san lucas
# Processing Record 35 of Set 4 | saint combs
# City not found. Skipping...
# Processing Record 36 of Set 4 | nalgonda
# Processing Record 37 of Set 4 | maragogi
# Processing Record 38 of Set 4 | lagoa
# Processing Record 39 of Set 4 | pevek
# Processing Record 40 of Set 4 | port alfred
# Processing Record 41 of Set 4 | sioux lookout
# Processing Record 42 of Set 4 | jalu
# Processing Record 43 of Set 4 | sur
# Processing Record 44 of Set 4 | plymouth
# Processing Record 45 of Set 4 | seinajoki
# Processing Record 46 of Set 4 | nara
# Processing Record 47 of Set 4 | camacha
# Processing Record 48 of Set 4 | san patricio
# Processing Record 49 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 50 of Set 4 | suruc
# Processing Record 1 of Set 5 | alvaraes
# Processing Record 2 of Set 5 | wamba
# Processing Record 3 of Set 5 | airai
# Processing Record 4 of Set 5 | haverfordwest
# Processing Record 5 of Set 5 | linkou
# Processing Record 6 of Set 5 | alice springs
# Processing Record 7 of Set 5 | laramie
# Processing Record 8 of Set 5 | provideniya
# Processing Record 9 of Set 5 | rapar
# Processing Record 10 of Set 5 | ambilobe
# Processing Record 11 of Set 5 | leningradskiy
# Processing Record 12 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 15 of Set 5 | celendin
# Processing Record 16 of Set 5 | samarai
# Processing Record 17 of Set 5 | linxia
# Processing Record 18 of Set 5 | cabedelo
# Processing Record 19 of Set 5 | providencia
# Processing Record 20 of Set 5 | hamilton
# Processing Record 21 of Set 5 | atocha
# Processing Record 22 of Set 5 | okha
# Processing Record 23 of Set 5 | dudinka
# Processing Record 24 of Set 5 | abu samrah
# Processing Record 25 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 5 | plettenberg bay
# Processing Record 27 of Set 5 | ahipara
# Processing Record 28 of Set 5 | binga
# Processing Record 29 of Set 5 | port lincoln
# Processing Record 30 of Set 5 | port hedland
# Processing Record 31 of Set 5 | tura
# Processing Record 32 of Set 5 | livingston
# Processing Record 33 of Set 5 | chapais
# Processing Record 34 of Set 5 | coquimbo
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | nome
# Processing Record 37 of Set 5 | kiunga
# Processing Record 38 of Set 5 | porto nacional
# Processing Record 39 of Set 5 | olga
# Processing Record 40 of Set 5 | hounde
# Processing Record 41 of Set 5 | pokaran
# Processing Record 42 of Set 5 | ribeira grande
# Processing Record 43 of Set 5 | arbuzynka
# Processing Record 44 of Set 5 | broome
# Processing Record 45 of Set 5 | honiara
# Processing Record 46 of Set 5 | avera
# Processing Record 47 of Set 5 | kuito
# Processing Record 48 of Set 5 | nhulunbuy
# Processing Record 49 of Set 5 | arraial do cabo
# Processing Record 50 of Set 5 | songea
# Processing Record 1 of Set 6 | korla
# Processing Record 2 of Set 6 | geraldton
# Processing Record 3 of Set 6 | newton
# Processing Record 4 of Set 6 | husavik
# Processing Record 5 of Set 6 | sayyan
# Processing Record 6 of Set 6 | hailey
# Processing Record 7 of Set 6 | jinchang
# Processing Record 8 of Set 6 | aquiraz
# Processing Record 9 of Set 6 | san policarpo
# Processing Record 10 of Set 6 | ukiah
# Processing Record 11 of Set 6 | saskylakh
# Processing Record 12 of Set 6 | lisakovsk
# Processing Record 13 of Set 6 | homnabad
# Processing Record 14 of Set 6 | zhuhai
# Processing Record 15 of Set 6 | guerrero negro
# Processing Record 16 of Set 6 | guadalupe y calvo
# Processing Record 17 of Set 6 | kavieng
# Processing Record 18 of Set 6 | potiskum
# Processing Record 19 of Set 6 | labuhan
# Processing Record 20 of Set 6 | saint george
# Processing Record 21 of Set 6 | tiksi
# Processing Record 22 of Set 6 | mackay
# Processing Record 23 of Set 6 | richards bay
# Processing Record 24 of Set 6 | port moresby
# Processing Record 25 of Set 6 | annau
# Processing Record 26 of Set 6 | zlobin
# Processing Record 27 of Set 6 | moreira sales
# Processing Record 28 of Set 6 | quebrada de arena
# Processing Record 29 of Set 6 | presidente epitacio
# Processing Record 30 of Set 6 | malinyi
# Processing Record 31 of Set 6 | malvern
# Processing Record 32 of Set 6 | sandpoint
# Processing Record 33 of Set 6 | batsfjord
# Processing Record 34 of Set 6 | seshcha
# Processing Record 35 of Set 6 | mumford
# Processing Record 36 of Set 6 | kosino
# Processing Record 37 of Set 6 | cherskiy
# Processing Record 38 of Set 6 | leh
# Processing Record 39 of Set 6 | taywarah
# Processing Record 40 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 6 | placer
# Processing Record 42 of Set 6 | san jose
# Processing Record 43 of Set 6 | padang
# Processing Record 44 of Set 6 | olafsvik
# Processing Record 45 of Set 6 | iquique
# Processing Record 46 of Set 6 | lucapa
# Processing Record 47 of Set 6 | williams lake
# Processing Record 48 of Set 6 | mildura
# Processing Record 49 of Set 6 | roald
# Processing Record 50 of Set 6 | vao

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
